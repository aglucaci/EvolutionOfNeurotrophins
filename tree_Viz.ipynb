027008950.2:0.7335768918,((XM_022667082.1:0.4120222067,XM_017706136.1:0.3910854501):0.1648585832,((XM_026937384.2:0.0860440802,XM_027137186.1:0.3429406932):0.0000029526,XM_017458315.1:0.2773790442):1.0672591942):0.0544572620):0.2158266047):0.2094351621,XM_030766568.1:1.2273885230):0.5158117701):0.6522375569):0.5099944804,XM_023810716.1:4.1635649198):1.7716927510,XM_015338619.1:3.4127661900):1.2278169919,XM_028794224.1:2.9333985652):1.9869660473,((XM_033038635.1:4.1892981429,XM_020536678.1:2.5812254464):1.6017322941,XM_007887667.1:1.7414021344):4.9173226649):1.1804566382):0.4182267441,((XM_029582984.1:0.8900557880,(XM_033928531.1:1.3061496918,XM_030199447.1:0.5087302299):0.7482452791):0.6880981724,(XM_031899708.1:1.1274040061,XM_018567792.1:1.6629659011):1.2559718179):0.2262738465):0.6709495492):0.4744090282):0.5960216249):1.3613113753):0.0127615229,XM_012523604.2:0.5277035313):0.0589958209):0.0923068315,((XM_006864851.1:0.3268837085,XM_004708253.2:1.0509560663):0.0763743568,XM_006883713.1:0.3248300082):0.1053922535):0.0340155486):0.0131912515,((((XM_027936596.1:0.0000021139,(XM_005328048.2:0.0106082633,XM_026412272.1:0.0212692481):0.0647710502):0.4681565547,XM_015476449.1:0.0000028240):0.2063966751,((XM_004660846.2:1.2627227651,((((XM_007653166.4:0.3449637443,XM_029555090.1:0.3826773724):0.2847416561,(((NM_001048142.1:0.0000025309,XM_021151236.2:0.0102097859):0.0086531316,XM_021192829.2:0.0459416152):0.0839605182,(NM_001270630.1:0.0098704425,XM_032903861.1:0.0131845057):0.0268163175):1.0829984708):0.9366994163,XM_031371313.1:0.1695184435):0.0522421154,XM_028882376.1:0.1358419073):0.1798075685):0.1238330224,(XM_020177315.1:0.2501798895,XM_013019592.1:0.4615403491):0.0267496326):0.0270151140):0.0660213486,XM_014591303.2:1.0186244683):0.0305446433):0.0716126806,(XM_012649556.1:0.1532701433,XM_012814047.1:0.1539859643):0.1003150155):0.0240036397):0.0803936709):0.0268690870,XM_009007854.3:0.1150713649):0.0256453808,XM_034932318.1:0.0047316665):0.0120362362):0.0000021896,XM_004050851.2:0.0120183051);"

# %%
def layout(node):
    if node.is_leaf():
        N = AttrFace("name", fsize=0)
        faces.add_face_to_node(N, node, 0, position="aligned")
    #end if
#end method

def get_example_tree():

    # Set dashed blue lines in all leaves
    nst1 = NodeStyle()
    nst1["bgcolor"] = "LightSteelBlue"
    
    nst2 = NodeStyle()
    nst2["bgcolor"] = "Moccasin"
    
    nst3 = NodeStyle()
    nst3["bgcolor"] = "DarkSeaGreen"
    
    nst4 = NodeStyle()
    nst4["bgcolor"] = "Khaki"

    nst5 = NodeStyle()
    nst5["bgcolor"] = "LightBlue"
    
    nst6 = NodeStyle()
    nst6["bgcolor"] = "LightRed"
    
    nst7 = NodeStyle()
    nst7["bgcolor"] = "LightGreen"
    
    nst8 = NodeStyle()
    nst8["bgcolor"] = "LightPurple"

    t = Tree(TREE_STRING)
    
    #for n in t.traverse():
    #    n.dist = 0
    
    nstyle = NodeStyle()
    nstyle["shape"] = "circle"
    nstyle["size"] = 1
    nstyle["fgcolor"] = "black"

    for n in t.traverse():
        n.set_style(nstyle)
    
    #n1 = t.get_common_ancestor('NM_001709.5', 'NM_001012441.1', 'XM_015114598.2', 'XM_011710310.2', 'XM_005578346.2', 'XM_002821931.2', 'XM_032166370.1', 'XM_003254347.2', 'XM_003919940.2', 'XM_032283691.1', 'XM_017538722.1', 'XM_012452238.1', 'XM_020286534.1', 'XM_011964715.1', 'XM_012031697.1', 'XM_008003703.1', 'XM_017948537.3', 'XM_025358305.1', 'XM_010374529.2', 'XM_017858805.1', 'XM_033205475.1', 'XM_011936307.1', 'XM_023230347.2', 'XM_008050727.1', 'XM_012649556.1', 'XM_012814047.1', 'XM_009007854.3', 'XM_034932318.1', 'XM_004050851.2')
    #n1.set_style(nst1)
    
    #n2 = t.get_common_ancestor("b1", "b2", "b3", "b4")
    #n2.set_style(nst2)
    
    #n3 = t.get_common_ancestor("c1", "c2", "c3")
    #n3.set_style(nst3)
    
    #n4 = t.get_common_ancestor("b3", "b4")
    #n4.set_style(nst4)
    
    #Chondrichthyes
    n1 = t.get_common_ancestor('XM_033038635.1', 'XM_020536678.1', 'XM_007887667.1')
    n1.set_style(nst1)
                               
    #Amphibia
    n2 = t.get_common_ancestor('XM_029582984.1', 'XM_033928531.1', 'XM_030199447.1', 'XM_031899708.1', 'XM_018567792.1')
    n2.set_style(nst2)
    
    #Amniota
    n3 = t.get_common_ancestor('NM_001709.5', 'NM_001012441.1', 'XM_015114598.2', 'XM_011710310.2', 'XM_005578346.2', 'XM_002821931.2', 'XM_032166370.1', 'XM_003254347.2', 'XM_003919940.2', 'XM_032283691.1', 'XM_017538722.1', 'XM_012452238.1', 'XM_020286534.1', 'XM_029957152.1', 'NM_001009828.1', 'XM_030333208.1', 'XM_015544869.1', 'XM_004585440.1', 'XM_008584165.1', 'XM_011964715.1', 'XM_012031697.1', 'XM_008003703.1', 'XM_017948537.3', 'XM_025358305.1', 'XM_010374529.2', 'XM_017858805.1', 'XM_033205475.1', 'XM_011936307.1', 'XM_023230347.2', 'XM_008050727.1', 'XM_005654684.3', 'XM_005216334.4', 'XM_027562786.1', 'XM_005890667.2', 'XM_010831788.1', 'XM_019974522.1', 'XM_006068006.2', 'XM_012096129.3', 'XM_005690025.2', 'XM_020903256.1', 'XM_030864833.1', 'XM_027115138.1', 'XM_019947883.2', 'XM_004263941.3', 'XM_007461679.1', 'XM_022583733.1', 'XM_029207934.1', 'XM_028501134.1', 'XM_024764694.1', 'XM_032641481.1', 'XM_007180991.1', 'XM_006195083.3', 'XM_031459858.1', 'XM_031681074.1', 'XM_010964743.1', 'XM_017667612.1', 'XM_004418542.2', 'NM_001081787.1', 'XM_008522855.1', 'XM_014831462.1', 'XM_014545223.1', 'XM_008148947.2', 'XM_006753948.2', 'XM_023756374.1', 'XM_016206154.1', 'XM_013147262.2', 'XM_004851581.3', 'XM_033764060.1', 'XM_004644113.2', 'XM_005401751.2', 'XM_004682964.2', 'XM_005633263.3', 'XM_025459816.2', 'XM_026018600.1', 'XM_004408653.1', 'XM_028117708.
_032112640.1', 'XM_019474511.1', 'XM_009334518.1', 'XM_005235654.2', 'XM_005436172.2', 'XM_009877094.1', 'XM_009483459.1', 'XM_009461407.1', 'XM_009709132.1', 'XM_009901330.1', 'XM_009584497.1', 'XM_009506018.1', 'XM_009892685.1', 'XM_014953771.1', 'XM_009635573.1', 'XM_009555765.1', 'XM_010208602.1', 'XM_010153077.1', 'XM_010140876.1', 'XM_009807008.1', 'XM_010124146.1', 'XM_009919440.1', 'XM_010563723.1', 'XM_009961628.1', 'XM_030039828.1', 'XM_009937137.1', 'XM_010298236.1', 'XM_009084069.1', 'XM_009097040.3', 'XM_005426937.2', 'XM_030950284.1', 'XM_014270822.2', 'XM_005046293.2', 'XM_008946081.1', 'XM_026041160.1', 'XM_010226640.1', 'XM_010004242.1', 'XM_030451239.1', 'XM_010167688.2', 'XM_010284015.1', 'XM_026850900.1', 'XM_009987364.1', 'XM_026122142.1', 'XM_009679447.1', 'XM_026073096.1', 'XM_013959299.1', 'XM_006020695.3', 'XM_019476630.1', 'XM_019519496.1', 'XM_019552325.1', 'XM_014574007.2', 'XM_005306369.3', 'XM_024214871.2', 'XM_034769999.1', 'XM_030560212.1', 'XM_032770859.1', 'XM_027830119.1', 'XM_033151141.1', 'XM_028729457.1', 'XM_035117800.1', 'XM_008118081.2', 'XM_020790423.1', 'XM_025169672.1', 'XM_032228844.1', 'XM_014061142.1', 'XM_026664626.1', 'XM_026704474.1', 'XM_015815390.1', 'XM_034417213.1', 'XM_015425686.1')
    n8.set_style(nst7)
    
    ts = TreeStyle()
    
    #ts.layout_fn = layout
    ts.show_leaf_name = False

    ts.mode = "c"
    ts.root_opening_factor = 1
    return t, ts

if __name__ == "__main__":
    t, ts = get_example_tree()
    #t.render("node_background.png", w=400, tree_style=ts)
    #nstyle = NodeStyle()
    #nstyle["shape"] = "sphere"
    #nstyle["size"] = 1
    #nstyle["fgcolor"] = "black"

    #for n in t.traverse():
    #    n.set_style(nstyle)
    
    t.render("node_background.png", w=400, tree_style=ts)
    t.show(tree_style=ts)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ete3-3.1.2-py3.7.egg/ete3/treeview/qt4_gui.py in on_actionRender_selected_region_triggered(self)
#     394     @QtCore.pyqtSlot()
#     395     def on_actionRender_selected_region_triggered(self):
# --> 396         if not self.scene.selector.isVisible():
#     397             return QMessageBox.information(self, "!",\
#     398                                               "You must select a region first")
#
# AttributeError: '_TreeScene' object has no attribute 'selector'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.7/site-packages/ete3-3.1.2-py3.7.egg/ete3/treeview/qt4_gui.py in on_actionRender_selected_region_triggered(self)
# ...

# %%
def layout(node):
    if node.is_leaf():
        N = AttrFace("name", fsize=0)
        faces.add_face_to_node(N, node, 0, position="aligned")
    #end if
#end method

def get_example_tree():

    # Set dashed blue lines in all leaves
    nst1 = NodeStyle()
    nst1["bgcolor"] = "LightSteelBlue"

    t = Tree(TREE_STRING)
    
    #for n in t.traverse():
    #    n.dist = 0
    
    #nstyle = NodeStyle()
    #nstyle["shape"] = "circle"
    #nstyle["size"] = 1
    #nstyle["fgcolor"] = "black"

    #for n in t.traverse():
    #    n.set_style(nstyle)
                          
    #Primates
    n1 = t.get_common_ancestor('NM_001709.5', 'NM_001012441.1', 'XM_015114598.2', 'XM_011710310.2', 'XM_005578346.2', 'XM_002821931.2', 'XM_032166370.1', 'XM_003254347.2', 'XM_003919940.2', 'XM_032283691.1', 'XM_017538722.1', 'XM_012452238.1', 'XM_020286534.1', 'XM_011964715.1', 'XM_012031697.1', 'XM_008003703.1', 'XM_017948537.3', 'XM_025358305.1', 'XM_010374529.2', 'XM_017858805.1', 'XM_033205475.1', 'XM_011936307.1', 'XM_023230347.2', 'XM_008050727.1', 'XM_012649556.1', 'XM_012814047.1', 'XM_009007854.3', 'XM_034932318.1', 'XM_004050851.2')
    n1.set_style(nst1)
    
    ts = TreeStyle()
    
    #ts.layout_fn = layout
    ts.show_leaf_name = False

    ts.mode = "c"
    ts.root_opening_factor = 1
    return t, ts

if __name__ == "__main__":
    t, ts = get_example_tree()
    #t.render("node_background.png", w=400, tree_style=ts)
    #nstyle = NodeStyle()
    #nstyle["shape"] = "sphere"
    #nstyle["size"] = 1
    #nstyle["fgcolor"] = "black"

    #for n in t.traverse():
    #    n.set_style(nstyle)
    
    t.render("node_background.png", w=400, tree_style=ts)
    t.show(tree_style=ts)

# %%
ncbi = NCBITaxa()
ncbi.update_taxonomy_database()
# Out:
# Updating taxdump.tar.gz from NCBI FTP site (via HTTP)...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-c9aba9599609> in <module>
#       1 ncbi = NCBITaxa()
# ----> 2 ncbi.update_taxonomy_database()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ete3-3.1.2-py3.7.egg/ete3/ncbi_taxonomy/ncbiquery.py in update_taxonomy_database(self, taxdump_file)
#     129         """
#     130         if not taxdump_file:
# --> 131             update_db(self.dbfile)
#     132         else:
#     133             update_db(self.dbfile, taxdump_file)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/ete3-3.1.2-py3.7.egg/ete3/ncbi_taxonomy/ncbiquery.py in update_db(dbfile, targz_file)
#     767                 do_download = True
#     768                 print('Updating taxdump.tar.gz from NCBI FTP site (via HTTP)...', file=sys.stderr)
# ...

# %%
DATA_DICT = {}

# %%
# The following looks up NCBI Taxon ID from Accession IDs
# Then uses that Taxon ID to get the complete taxnomic lineage of of that species.

Entrez.email = "aglucaci@gmail.com"

def main():
    global DATA_DICT
    t = Tree(TREE_STRING);
    count = 1
    for ACCESSION in t.get_leaf_names():
        #print("Processing:", ACCESSION)
        #if ACCESSION in list(df["ACCESSION"]): #skip it
        #    count = len(df["ACCESSION"])
        #    continue
        try:
            handle = Entrez.esummary(db="nucleotide", id=ACCESSION, rettype="gb", retmode="text", retmax=1)
            records = Entrez.parse(handle)
        except:
            print("# error, sleeping")
            time.sleep(5)
            handle = Entrez.esummary(db="nucleotide", id=ACCESSION, rettype="gb", retmode="text", retmax=1)
            records = Entrez.parse(handle)
        #end try
        
        
        #records = Entrez.parse(handle)
        
        
        
        #handle.close()
        #time.sleep(2)
        
        #print(records[0])
        for record in records:
            #print(record["TaxId"])
            TAXON_ID = record["TaxId"]
            print(count, "Processing:", ACCESSION, TAXON_ID)
            #break

            ncbi = NCBITaxa()

            lineage = ncbi.get_lineage(TAXON_ID)
            #print(lineage)

            # [1, 131567, 2759, 33154, 33208, 6072, 33213, 33511, 7711, 89593, 7742,
            # 7776, 117570, 117571, 8287, 1338369, 32523, 32524, 40674, 32525, 9347,
            # 1437010, 314146, 9443, 376913, 314293, 9526, 314295, 9604, 207598, 9605,
            # 9606]

            names = ncbi.get_taxid_translator(lineage)
            #print([names[taxid] for taxid in lineage])

            DATA_DICT[str(count)] = {"ACCESSION":ACCESSION, "TAXON_ID": TAXON_ID, "LINEAGE": [names[taxid] for taxid in lineage], "TITLE":record["Title"]}
            count += 1
            # [u'root', u'cellular organisms', u'Eukaryota', u'Opisthokonta', u'Metazoa',
            # u'Eumetazoa', u'Bilateria', u'Deuterostomia', u'Chordata', u'Craniata',
            # u'Vertebrata', u'Gnathostomata', u'Teleostomi', u'Euteleostomi',
            # u'Sarcopterygii', u'Dipnotetrapodomorpha', u'Tetrapoda', u'Amniota',
            # u'Mammalia', u'Theria', u'Eutheria', u'Boreoeutheria', u'Euarchontoglires',
            # u'Primates', u'Haplorrhini', u'Simiiformes', u'Catarrhini', u'Hominoidea',
            # u'Hominidae', u'Homininae', u'Homo', u'Homo sapiens']

            #print()
        #end inner for
        handle.close()

    #end for
#end method

main()

"""

try:
    main()
except:
    try:
        main() # second attempt
    except:
        pass
    #end try
#end try
"""
# Out:
# 1 Processing: NM_001709.5 9606
# 2 Processing: NM_001012441.1 9598
# 3 Processing: XM_015114598.2 9544
# 4 Processing: XM_011710310.2 9545
# 5 Processing: XM_005578346.2 9541
# 6 Processing: XM_002821931.2 9601
# 7 Processing: XM_032166370.1 81572
# 8 Processing: XM_003254347.2 61853
# 9 Processing: XM_003919940.2 39432
# 10 Processing: XM_032283691.1 9515
# 11 Processing: XM_017538722.1 1737458
# 12 Processing: XM_012452238.1 37293
# 13 Processing: XM_020286534.1 30608
# 14 Processing: XM_029957152.1 37032
# 15 Processing: NM_001009828.1 9685
# 16 Processing: XM_030333208.1 61383
# 17 Processing: XM_015544869.1 74533
# 18 Processing: XM_004585440.1 9978
# 19 Processing: XM_008584165.1 482537
# 20 Processing: XM_011964715.1 9568
# 21 Processing: XM_012031697.1 9531
# 22 Processing: XM_008003703.1 60711
# 23 Processing: XM_017948537.3 9555
# 24 Processing: XM_025358305.1 9565
# 25 Processing: XM_010374529.2 61622
# 26 Processing: XM_017858805.1 61621
# ...

# %%
df_load = pd.read_csv("BDNF_TAXONOMY.csv") 
df_load
# Out:
#      Unnamed: 0       ACCESSION  TAXON_ID  \
# 0             1     NM_001709.5      9606
# 1             2  NM_001012441.1      9598
# 2             3  XM_015114598.2      9544
# 3             4  XM_011710310.2      9545
# 4             5  XM_005578346.2      9541
# ..          ...             ...       ...
# 303         304  XM_012649556.1    379532
# 304         305  XM_012814047.1     30611
# 305         306  XM_009007854.3      9483
# 306         307  XM_034932318.1      9597
# 307         308  XM_004050851.2      9595
#
#                                                LINEAGE  \
# 0    ['root', 'cellular organisms', 'Eukaryota', 'O...
# 1    ['root', 'cellular organisms', 'Eukaryota', 'O...
# 2    ['root', 'cellular organisms', 'Eukaryota', 'O...
# 3    ['root', 'cellular organisms', 'Eukaryota', 'O...
# 4    ['root', 'cellular organisms', 'Eukaryota', 'O...
# ..                                                 ...
# 303  ['root', 'cellular organisms', 'Eukaryota', 'O...
# ...

# %%
#Need the following clades
    
#Chondrichthyes
#Amphibia
#Amniota
#Cladistia
#Actinopteri  
#Coelacanthimorpha 
#Dipnotetrapodomorpha

#CLADES = ["Chondrichthyes","Amphibia","Amniota","Cladistia","Actinopteri","Coelacanthimorpha","Dipnotetrapodomorpha"]
#Mammalia
#CLADES = ["Primates", "Laurasiatheria", "Dermoptera"]

#CLADES = ["Chondrichthyes","Amphibia","Amniota","Cladistia","Actinopteri","Coelacanthimorpha","Mammalia", "Sauropsida"]

#CLADES = ["Chondrichthyes","Amphibia","Amniota","Cladistia","Actinopteri","Coelacanthimorpha","Boreoeutheria", "Afrotheria","Sauropsida"]

CLADES = ["Simiiformes"]

def lookup_clade(clade):
    accession_ids = []
    
    # Look for the clade in the df["LINEAGE"]
    for n, value in enumerate(df_load["LINEAGE"]): 
        turn_into_list = value.replace("'", "").replace(" ", "").replace("[", "").replace("]", "").split(",")
    
        #if found, add it to the accession_ids
        if clade in turn_into_list:
            accession_ids.append(df_load["ACCESSION"][n])
        #end if
    #end for
    return accession_ids
            
#end method

#group = lookup_clade("Chondrichthyes")

for clade in CLADES:
    group = lookup_clade(clade)
    print(clade)
    print(group)
    print()
#end for

# %%
THE_SET = []
df_load.values.tolist()

for value in df_load["LINEAGE"]: 
    turn_into_list = value.replace("'", "").replace(" ", "").replace("[", "").replace("]", "").split(",")
    #print(type(turn_into_list))
    #print(turn_into_list[15])
    #print(value[9)
    #for item in value: print(item)
    #print()
    THE_SET.append(turn_into_list[-4])
#end for
    
print(set(THE_SET))
# Out:
# {'Macroscelidea', 'Rajiformes', 'Clupeidae', 'Cebidae', 'Felidae', 'Percidae', 'Castorimorpha', 'Tinamiformes', 'Synbranchoidei', 'Dicroglossidae', 'Odontoceti', 'Saimiriinae', 'Rhinolophidae', 'Apodiformes', 'Dasyuromorphia', 'Strigiformes', 'Siluroidei', 'Apogonidae', 'Diprotodontia', 'Elapidae', 'Eupercariaincertaesedis', 'Monotremata', 'Chimaeriformes', 'Adrianichthyidae', 'Gobiidae', 'Labriformes', 'Estrildidae', 'Ovalentariaincertaesedis', 'Apodidae', 'Rhinocerotidae', 'Equidae', 'Cebinae', 'Characoidei', 'Falconiformes', 'Coraciiformes', 'Casuariiformes', 'Spalacidae', 'Cyprinodontinae', 'Phocoenidae', 'Gymnophiona', 'Hominoidea', 'Suina', 'Didelphidae', 'Scandentia', 'Canidae', 'Testudinoidea', 'Gruidae', 'Testudinidae', 'Iguania', 'Semionotiformes', 'Blenniidae', 'Syngnathidae', 'Anserinae', 'Osphronemidae', 'Cyprinidae', 'Apterygidae', 'Osteoglossiformes', 'Cingulata', 'Procellariiformes', 'Dipodidae', 'Cercopithecidae', 'Psittaciformes', 'Eulipotyphla', 'Gekkonidae', 'Anab
# ...

# %%
PRIMATES = []


for item in DATA_DICT.keys():
    if "Primates" in DATA_DICT[item]["LINEAGE"]:
        #print(DATA_DICT[item]["ACCESSION"])
        PRIMATES.append(DATA_DICT[item]["ACCESSION"])
    #end if
#end for

print(PRIMATES)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-853c38bdce96> in <module>
#       1 PRIMATES = []
# ----> 2 for item in DATA_DICT.keys():
#       3     if "Primates" in DATA_DICT[item]["LINEAGE"]:
#       4         #print(DATA_DICT[item]["ACCESSION"])
#       5         PRIMATES.append(DATA_DICT[item]["ACCESSION"])
#
# NameError: name 'DATA_DICT' is not defined

# %%
TAXA_SET_len = []
TAXA_SET = []

for item in DATA_DICT.keys():
    #print(item, DATA_DICT[item]["LINEAGE"])
    #DATA_DICT[item]["LINEAGE"]
    TAXA_SET_len.append(len(DATA_DICT[item]["LINEAGE"]))
    TAXA_SET.append(DATA_DICT[item]["LINEAGE"][len(DATA_DICT[item]["LINEAGE"]) - 9])
    #print()

print(min(TAXA_SET_len), max(TAXA_SET_len))

print(set(TAXA_SET))

# %%
df = pd.DataFrame.from_dict(DATA_DICT, orient='index')
df
df.to_csv("BDNF_TAXONOMY_v02.csv")

# %%
# Lets do some assigning via the df

# %%
a = ['root',
   'cellular organisms',
   'Eukaryota',
   'Opisthokonta',
   'Metazoa',
   'Eumetazoa',
   'Bilateria',
   'Deuterostomia',
   'Chordata',
   'Craniata',
   'Vertebrata',
   'Gnathostomata',
   'Teleostomi',
   'Euteleostomi',
   'Sarcopterygii',
   'Dipnotetrapodomorpha',
   'Tetrapoda',
   'Amniota',
   'Mammalia',
   'Theria',
   'Eutheria',
   'Boreoeutheria',
   'Euarchontoglires',
   'Primates',
   'Haplorrhini',
   'Simiiformes',
   'Catarrhini',
   'Cercopithecoidea',
   'Cercopithecidae',
   'Cercopithecinae',
   'Macaca',
   'Macaca fascicularis']

# %%
if "NM_001012441.1" in list(df["ACCESSION"]): print("TRUE")
# Out:
# TRUE

# %%
len(df["ACCESSION"])
# Out:
# 308

# %%
for ACCESSION in t.get_leaf_names():
    #handle = Entrez.esummary(db="nucleotide", id=ACCESSION, rettype="gb", retmode="text", retmax=1)
    handle = Entrez.esummary(db="nucleotide", id=ACCESSION)
    record = Entrez.parse(handle)
    handle.close()
    print(record.read())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-94-5910186226e4> in <module>
#       4     record = Entrez.parse(handle)
#       5     handle.close()
# ----> 6     print(record.read())
#
# AttributeError: 'generator' object has no attribute 'read'

# %%
# Given the list, get taxnomic orders
import subprocess
MAPPING_DICT = {}

def system_call(command):
    p = subprocess.Popen([command], stdout=subprocess.PIPE, shell=True)
    return p.stdout.read()


for item in t.get_leaf_names():
    #cmd = esearch -db nuccore  -query NC_001422.1|elink -target taxonomy|efetch -format uid
    cmd = "esearch -db nuccore -query " + item + "|elink -target taxonomy|efetch -format uid"
    #result = subprocess.check_output(batcmd, shell=True)
    #result = subprocess.check_output(cmd, shell=True)
    #result = system_call(cmd)
    
    os.system(cmd + ' >> output.txt')
    
    #print(cmd, result)
    MAPPING_DICT[item] = ""
# Out:
# esearch -db nuccore -query NM_001709.5|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query NM_001012441.1|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_015114598.2|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_011710310.2|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_005578346.2|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_002821931.2|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_032166370.1|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_003254347.2|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_003919940.2|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_032283691.1|elink -target taxonomy|efetch -format uid
# esearch -db nuccore -query XM_017538722.1|elink -target taxonomy|efetch -format uid
# ...

# %%
# #################################################################################################################
# #################################################################################################################
# #################################################################################################################

# #################################################################################################################
# #################################################################################################################
# #################################################################################################################

# #################################################################################################################
# #################################################################################################################
# #################################################################################################################

# %%
import argparse
from Bio import Entrez
import time
import json
import csv
from collections import Counter

# %%
search = Entrez.esearch(db="nucleotide", retmax=1, term="XM_032283691.1", idtype="acc")
records = Entrez.read(search)
acc_nums = records["IdList"]
#print(f"FOUND {len(acc_nums)} {virus} HITS\n")
#print("SEARCHING FOR METADATA... BE PATIENT\n")

print(records)
# Out:
# {'Count': '1', 'RetMax': '1', 'RetStart': '0', 'IdList': ['XM_032283691.1'], 'TranslationSet': [], 'QueryTranslation': ''}

# %%
handle = Entrez.efetch(db="nucleotide", id=acc, rettype="gb", retmode="xml")
record = Entrez.read(handle)[0]"XM_032283691.1"

# %%
handle = Entrez.esummary(db="nucleotide", id="XM_032283691.1", rettype="gb", retmode="text")
records = Entrez.parse(handle)

print(records)
for record in records:
        for item in record:
            print(item, record[item])
        #print(record)
# Out:
# <generator object DataHandler.parse at 0x7ffd08e0cdd0>
# Item []
# Id 1804367552
# Caption XM_032283691
# Title PREDICTED: Sapajus apella brain derived neurotrophic factor (BDNF), transcript variant X1, mRNA
# Extra gi|1804367552|ref|XM_032283691.1|[1804367552]
# Gi 1804367552
# CreateDate 2020/02/02
# UpdateDate 2020/02/02
# Flags 512
# TaxId 9515
# Length 4053
# Status live
# ReplacedBy
# Comment
# AccessionVersion XM_032283691.1

# %%
#http://etetoolkit.org/docs/latest/tutorial/tutorial_ncbitaxonomy.html
from ete3 import NCBITaxa
ncbi = NCBITaxa()
ncbi.update_taxonomy_database()
# Out:
# Updating taxdump.tar.gz from NCBI FTP site (via HTTP)...
# Done. Parsing...
# Loading node names...
# 2274616 names loaded.
# 228584 synonyms loaded.
# Loading nodes...
# 2274616 nodes loaded.
# Linking nodes...
# Tree is loaded.
# Updating database: /Users/user/.etetoolkit/taxa.sqlite ...
#  2274000 generating entries...
# Uploading to /Users/user/.etetoolkit/taxa.sqlite

# %%
from ete3 import NCBITaxa
ncbi = NCBITaxa()

lineage = ncbi.get_lineage(9606)
print lineage

# [1, 131567, 2759, 33154, 33208, 6072, 33213, 33511, 7711, 89593, 7742,
# 7776, 117570, 117571, 8287, 1338369, 32523, 32524, 40674, 32525, 9347,
# 1437010, 314146, 9443, 376913, 314293, 9526, 314295, 9604, 207598, 9605,
# 9606]

names = ncbi.get_taxid_translator(lineage)
print [names[taxid] for taxid in lineage]

# [u'root', u'cellular organisms', u'Eukaryota', u'Opisthokonta', u'Metazoa',
# u'Eumetazoa', u'Bilateria', u'Deuterostomia', u'Chordata', u'Craniata',
# u'Vertebrata', u'Gnathostomata', u'Teleostomi', u'Euteleostomi',
# u'Sarcopterygii', u'Dipnotetrapodomorpha', u'Tetrapoda', u'Amniota',
# u'Mammalia', u'Theria', u'Eutheria', u'Boreoeutheria', u'Euarchontoglires',
# u'Primates', u'Haplorrhini', u'Simiiformes', u'Catarrhini', u'Hominoidea',
# u'Hominidae', u'Homininae', u'Homo', u'Homo sapiens']
